# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %%
train_df = spark.table("predictive_cataglog.gold_layer.labeled_table")

# %%
train_df.limit(2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
train_df.groupBy("failure_label").count().show()
# Out:
# +-------------+-----+
# |failure_label|count|
# +-------------+-----+
# |            0|17531|
# |            1| 3100|
# +-------------+-----+

# %%
train_df.filter(col("RUL").isNull()).count()
# Out:
# 0
