# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
bronze_df = spark.table("predictive_cataglog.bronze_layer.bronze_table")

# %%
dq_bronze = {
    "null_engine_id": bronze_df.filter(col("engine_id").isNull()).count(),
    "null_cycle": bronze_df.filter(col("cycle").isNull()).count(),
    "invalid_cycle": bronze_df.filter(col("cycle") <= 0).count()
}

dq_bronze
# Out:
# {'null_engine_id': 0, 'null_cycle': 0, 'invalid_cycle': 0}

# %%
bronze_df.count()
# Out:
# 20631

# %%
import builtins
bronze_status = "PASS" if builtins.sum(dq_bronze.values()) == 0 else "FAIL"
bronze_status
# Out:
# 'PASS'
