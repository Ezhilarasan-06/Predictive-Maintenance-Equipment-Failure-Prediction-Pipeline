# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %%
labels_df = spark.table("predictive_cataglog.gold_layer.labeled_table")

# %%
labels_df.groupBy("failure_label").count().show()
# Out:
# +-------------+-----+
# |failure_label|count|
# +-------------+-----+
# |            0|17531|
# |            1| 3100|
# +-------------+-----+

# %%
labels_df.filter(
    (col("RUL") <= 30) & (col("failure_label") != 1)
).count()
# Out:
# 0
